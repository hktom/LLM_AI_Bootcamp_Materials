# %% [markdown]
# # **Fine-tuning LLMs for Financial Sentiment Classification! ( Open Source)**
#
# **Welcome back, AI Tuner!** 👋
#
# In previous projects, we used pre-trained LLMs "off-the-shelf" (zero-shot) or with specific prompts. Now, we'll dive into **fine-tuning**, the process of adapting a pre-trained model to perform exceptionally well on a *specific* task and dataset.
#
# We'll tackle **financial news sentiment classification** using the `Daniel-ML/sentiment-analysis-for-financial-news-v2` dataset, which contains financial news labeled as 'positive', 'negative', or 'neutral'.
#
# **What We'll Build & Compare:**
#
# A system to classify Financial News, comparing two different approaches:
# 1.  **Zero-Shot Open Source:** Using a pre-trained, small open-source model (like Gemma-1B) without any fine-tuning.
# 2.  **Fine-Tuned Open Source:** Fine-tuning the *same* open-source model on this dataset within Colab using efficient techniques (PEFT/LoRA).
#
#
# **What You'll Learn (The Core Skills):**
#
# *   **The Concept of Fine-tuning:** Why and when to adapt pre-trained models.
# *   **Using Hugging Face `datasets`:** Loading and preparing specific datasets.
# *   **PEFT / LoRA:** Understanding Parameter-Efficient Fine-Tuning techniques that make tuning large models feasible on limited hardware (like Colab GPUs!).
# *   **Using Hugging Face `trl` & `SFTTrainer`:** The modern way to easily fine-tune `transformers` models for supervised tasks (like classification).
# *   **Preparing Data for Fine-tuning:** Formatting your dataset correctly for both `SFTTrainer` and external APIs (like OpenAI).
# *   **Using the OpenAI Fine-tuning API:** Creating and running fine-tuning jobs programmatically.
# *   **Classification Evaluation:** Calculating metrics like Accuracy, Precision, Recall, and F1-score using `scikit-learn`.
# *   **Comparing Model Performance:** Systematically evaluating different modeling approaches on the same task.
#
# **Tech Stack (The Tools We'll Use):**
#
# *   **Python & Google Colab (with GPU):** Our environment.
# *   **Hugging Face `transformers`, `datasets`, `accelerate`, `bitsandbytes`:** For OS models and data.
# *   **Hugging Face `peft`:** For Parameter-Efficient Fine-Tuning (LoRA).
# *   **Hugging Face `trl`:** For the `SFTTrainer`.
# *   **`openai`:** The library to interact with OpenAI's API (including fine-tuning).
# *   **`scikit-learn`:** For calculating evaluation metrics.
# *   **`torch`:** The underlying deep learning framework.

# %% [markdown]
# ## **Section 1: Setup - Gathering Our Fine-tuning Toolkit** 🛠️🔧
#
# We need a few extra libraries this time, specifically for fine-tuning and evaluation.
#
# **1. Installing Libraries:**
#
# *   `transformers`, `accelerate`, `bitsandbytes`, `torch`: Standard for running HF models efficiently.
# *   `datasets`: For loading our FOMC data.
# *   **`peft`**: Enables Parameter-Efficient Fine-Tuning methods like LoRA.
# *   **`trl`**: Provides tools like `SFTTrainer` for easy Supervised Fine-tuning.
# *   `openai`: To interact with the OpenAI API (base models and fine-tuning).
# *   `scikit-learn`: For calculating classification performance metrics.

# %%
print("Installing necessary libraries for fine-tuning and evaluation...")

# Added peft, trl, openai, scikit-learn
# !pip install -q transformers accelerate bitsandbytes torch datasets peft trl openai scikit-learn gradio

print("Libraries installed successfully!")
# Out:
# Installing necessary libraries for fine-tuning and evaluation...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 39.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 26.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# **2. Logins & API Key Setup:**
#
# We need access to Hugging Face (for models/datasets) and OpenAI (for API calls and fine-tuning).
#
# **🚨 IMPORTANT - OpenAI API Key:**
# *   Fine-tuning OpenAI models **incurs costs**. Please check OpenAI's pricing page.
# *   Ensure your API key is set up correctly and has billing enabled if necessary.
# *   **Never** commit your API key directly into the notebook. Use environment variables or Colab secrets.

# %%
import os
from huggingface_hub import login, notebook_login
from openai import OpenAI

print("Attempting Hugging Face login...")

# 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
notebook_login()
print("HF Login successful (or token already present)!")


# --- OpenAI API Key Setup ---
# Option 1: Load from environment variable (recommended for security)
# load_dotenv()  # Load variables from a .env file if it exists
# openai_api_key = os.getenv("OPENAI_API_KEY")

# Option 2: Use Colab Secrets (click the key icon on the left sidebar)
from google.colab import userdata
openai_api_key = userdata.get('OPENAI_API_KEY')


openai_client = OpenAI(api_key=openai_api_key)
print("OpenAI client initialized.")
# Out:
# Attempting Hugging Face login...
# ...
# HF Login successful (or token already present)!
# OpenAI client initialized.

# %%
import torch
import transformers
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    TrainingArguments,
    BitsAndBytesConfig,  # For quantization config
)
from datasets import load_dataset, Dataset, DatasetDict
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training  # PEFT tools
from trl import SFTTrainer  # The fine-tuning trainer
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
import json  # For OpenAI JSONL format
import time  # For waiting on OpenAI jobs
from IPython.display import display, Markdown
import random

print("Core libraries imported.")

# Check for GPU availability (Crucial for fine-tuning)
if torch.cuda.is_available():
    print(f"GPU detected: {torch.cuda.get_device_name(0)}")
    # Get compute capability for bfloat16 check
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("GPU supports bfloat16: Setting torch default dtype to bfloat16.")
        torch.set_default_dtype(torch.bfloat16)
    else:
        print("GPU does not support bfloat16: Using float16.")
        torch.set_default_dtype(torch.float16)
else:
    print("❌ FATAL: No GPU detected. Fine-tuning requires a GPU. Please enable GPU in Runtime settings.")
    # Optionally exit or raise an error here


# Helper function for markdown display
def print_md(text):
    """Displays text as Markdown."""
    display(Markdown(text))
# Out:
# Core libraries imported.
# GPU detected: Tesla T4
# GPU does not support bfloat16: Using float16.

# %% [markdown]
# ### Practice Opportunity 1: Setup & GPU Check
#
#
# 1.  **GPU Capability:** Look at the output of the third cell. Is a GPU detected? Does it mention `bfloat16` support (common on newer GPUs like A100, H100) or fallback to `float16` (common on T4)? Why is confirming GPU presence absolutely critical for *this* project compared to previous ones?

# %% [markdown]
# -----------------------

# %% [markdown]
# ## **Section 2: Load and Prepare the Financial News Dataset** 📊🏦
#
# We'll load the `Daniel-ML/sentiment-analysis-for-financial-news-v2` dataset from the Hugging Face Hub. This dataset contains sentences from Financial News, with sentiments tagged.
#
# **Steps:**
# 1.  Load the dataset using `load_dataset`.
# 2.  Inspect its structure and labels.
# 3.  Split the data into training and testing sets to evaluate our models fairly.
# 4.  Format the data:
#     *   For **Open Source Fine-tuning (SFTTrainer)**: Create a text column containing a formatted prompt (instruction + input sentence).
#     *   For **OpenAI Fine-tuning**: Convert the data into the specific JSONL format required by their API.

# %%
dataset_id = "Daniel-ML/sentiment-analysis-for-financial-news-v2"


print(f"Loading dataset: {dataset_id}...")
labeled_dataset = load_dataset(dataset_id, split="train")  # Load the main split
print("Dataset loaded successfully!")

# --- Inspect the dataset ---
print("\n--- Dataset Information ---")
print(labeled_dataset)
print("\n--- Dataset Features ---")
print(labeled_dataset.features)
# Out:
# Loading dataset: Daniel-ML/sentiment-analysis-for-financial-news-v2...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/36.0 [00:00<?, ?B/s]
# pd_df_json.json:   0%|          | 0.00/788k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4846 [00:00<?, ? examples/s]
# Dataset loaded successfully!
#
# --- Dataset Information ---
# Dataset({
#     features: ['sentiment', 'text'],
#     num_rows: 4846
# })
#
# --- Dataset Features ---
# ...

# %%
# Unique lables in the dataset

labels = labeled_dataset.to_pandas()['sentiment'].unique().tolist()
print(f"Unique labels in the dataset: {labels}")
# Out:
# Unique labels in the dataset: ['neutral', 'negative', 'positive']

# %%
display(labeled_dataset.select(range(5)).to_pandas()[["text", "sentiment"]])
# Out:
#                                                 text sentiment
# 0  According to Gran , the company has no plans t...   neutral
# 1  Technopolis plans to develop in stages an area...   neutral
# 2  The international electronic industry company ...  negative
# 3  With the new production plant the company woul...  positive
# 4  According to the company 's updated strategy f...  positive

# %%
# --- Split Data into Train and Test Sets ---
print("\nSplitting data into Train (90%) and Test (10%)...")
train_test_split_ratio = 0.10
seed = 42  # for reproducibility

# Using datasets built-in method
split_dataset = labeled_dataset.train_test_split(
    test_size=train_test_split_ratio, seed=seed, shuffle=True,
)
train_dataset = split_dataset["train"]
test_dataset = split_dataset["test"]

print(f"Training set size: {len(train_dataset)}")
print(f"Test set size: {len(test_dataset)}")
print("\nTrain/Test Split Complete.")
# Out:
# Splitting data into Train (90%) and Test (10%)...
# Training set size: 4361
# Test set size: 485
#
# Train/Test Split Complete.

# %%
# --- Format Data for SFTTrainer (UPDATED for Gemma Chat Template) ---
# This function now requires the tokenizer to apply the template
# We'll define it here but apply it AFTER loading the tokenizer in the next sections

def format_for_sft_gemma(example, tokenizer):
    # Define the conversation structure
    system_prompt = "Classify the sentiment of the following sentence from News as positive, negative, or neutral."
    user_prompt = f"Sentence: {example['text']}"
    assistant_response = example['sentiment'] # The target label

    messages = [
        {"role": "user", "content": f"{system_prompt}\n{user_prompt}"}, # Combine system/user for simplicity here
        {"role": "assistant", "content": assistant_response}
    ]
    # Apply the tokenizer's chat template. add_generation_prompt=False includes the assistant part.
    # Ensure EOS token is added correctly by the template or manually if needed.
    formatted_text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=False)
    return {"text": formatted_text}

print("\nSFTTrainer formatting function defined (will be applied later).")
# Out:
# SFTTrainer formatting function defined (will be applied later).

# %% [markdown]
# ### Practice Opportunity 2: Data Inspection
#
# 1.  **Label Balance:** Look at the "Label Distribution" output. Are the classes ('positive', 'negative', 'neutral') roughly balanced, or is one significantly more common than others? How might class imbalance affect model training and evaluation?
# 2.  **SFT Format:** Examine the "Sample SFT format" output. Why does the text include the system prompt, user sentence, *and* the target label (`assistant_response`)? How does `SFTTrainer` use this format during training?

# %% [markdown]
# ## **Section 3: Zero-Shot Classification - Base Open Source Model** 🤖❓
#
# Before fine-tuning, let's see how a pre-trained open-source model performs on this task *without* any specific training on FOMC data. This gives us a baseline.
#
# We'll use the `google/gemma-3-1b-it` model again (or another small, capable model) loaded with 4-bit quantization.
#
# **Steps:**
# 1.  Load the quantized base model and tokenizer.
# 2.  Define a prompt template specifically for zero-shot classification (asking the model to output *only* the label).
# 3.  Create a function to run inference on the **test set**. This function needs to handle potential model outputs that aren't exactly one of the expected labels.
# 4.  Calculate and display evaluation metrics (Accuracy, Classification Report).

# %%
from tqdm.notebook import tqdm  # Progress bar

"""Need permission to access this gemma-3-1b-it"""

# --- Configuration ---
os_model_id = "google/gemma-3-1b-it" # <-- UPDATED Model ID


# --- Load Base Model (Quantized) ---
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4", # Recommended type
    bnb_4bit_compute_dtype=torch.float16
)

base_os_tokenizer = AutoTokenizer.from_pretrained(os_model_id)
# Set pad token if missing (Gemma often doesn't have one)
if base_os_tokenizer.pad_token is None:
    base_os_tokenizer.pad_token = base_os_tokenizer.eos_token
    print(f"Set pad_token to eos_token ({base_os_tokenizer.eos_token})")

# Load model
base_os_model = AutoModelForCausalLM.from_pretrained(
    os_model_id,
    quantization_config=quantization_config,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Ensure model pad token ID is updated if tokenizer's was
base_os_model.config.pad_token_id = base_os_tokenizer.pad_token_id
print("Base Gemma model and tokenizer loaded successfully.")
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/899 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Base Gemma model and tokenizer loaded successfully.

# %%
print("\nFormatting data for SFTTrainer (Gemma format)...")
sft_train_dataset =train_dataset.map(
              format_for_sft_gemma,
              fn_kwargs={"tokenizer": base_os_tokenizer},
              remove_columns=list(train_dataset.features)
              )
sft_test_dataset = test_dataset.map(
              format_for_sft_gemma,
              fn_kwargs={"tokenizer": base_os_tokenizer},
              remove_columns=list(test_dataset.features)
              )
print("SFTTrainer (Gemma) formatting complete.")
print("Sample SFT Gemma format:")
print(sft_train_dataset[0]['text'])
# Out:
# Formatting data for SFTTrainer (Gemma format)...
# ...
# Map:   0%|          | 0/485 [00:00<?, ? examples/s]
# SFTTrainer (Gemma) formatting complete.
# Sample SFT Gemma format:
# <bos><start_of_turn>user
# Classify the sentiment of the following sentence from News as positive, negative, or neutral.
# Sentence: These module products will be available for trials during 3Q-07 and for volume deliveries during 4Q-07 .<end_of_turn>
# <start_of_turn>model
# neutral<end_of_turn>

# %%
# --- Zero-Shot Classification Prompt Function (Gemma) ---
def create_zeroshot_prompt_gemma(sentence, tokenizer):

    """Creates zero-shot prompt using Gemma chat template."""
    system_prompt = f"Classify the sentiment of the following sentence from Financial News. Respond with ONLY ONE of the following labels: {', '.join(labels)}."
    user_prompt = f"Sentence: {sentence}"
    messages = [
        {"role": "user", "content": f"{system_prompt}\n{user_prompt}"},
    ]
    # Apply template, add_generation_prompt=True adds the assistant turn marker
    prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    return prompt

# %%
# --- Inference Function for Zero-Shot (Gemma) ---
# (This function is similar to before, but ensures correct prompt/EOS handling for Gemma)
def classify_zero_shot_os_gemma(sentence, model, tokenizer):


    prompt = create_zeroshot_prompt_gemma(sentence, tokenizer)
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=512).to(model.device)

    eos_id = tokenizer.eos_token_id          # usually 1 for Gemma
    pad_id = tokenizer.pad_token_id

    with torch.no_grad():

      outputs = model.generate(
          **inputs,
          max_new_tokens=10, # Increase this value (e.g., to 20 or 30)
          eos_token_id=eos_id,
          pad_token_id=eos_id,
          do_sample=False
          # You can remove top_p and top_k if they were present, as warnings suggest
      )
    # Decode only the generated part
    response_ids = outputs[0][inputs['input_ids'].shape[1]:]
    response_text = tokenizer.decode(response_ids, skip_special_tokens=True).strip()

    print(f"Generated Text (Gemma): {response_text}")

    # Clean and Validate Output (same logic as before)
    predicted_label = "Unknown"
    for label_text in labels:
        if label_text.lower() in response_text.lower(): # Simple check if label is present
              predicted_label = label_text
              break
    return predicted_label

# %%
# --- Evaluate on Test Set ---
base_os_predictions = [] # Renaming for clarity if needed, but reusing is fine
true_labels = []


print(f"\nRunning Zero-Shot Classification on Test Set ({len(test_dataset)} examples) using {os_model_id}...")
true_labels = [ex['sentiment'] for ex in test_dataset] # Ensure true labels are extracted

for example in tqdm(test_dataset):
    predicted_label = classify_zero_shot_os_gemma(example['text'], base_os_model, base_os_tokenizer)
    base_os_predictions.append(predicted_label)

print("\n--- Base Gemma Model: Zero-Shot Evaluation Results ---")
valid_indices = [i for i, p in enumerate(base_os_predictions) if p not in ["Error", "Unknown"]]
filtered_preds = [base_os_predictions[i] for i in valid_indices]
filtered_true = [true_labels[i] for i in valid_indices]


accuracy = accuracy_score(filtered_true, filtered_preds)
report = classification_report(filtered_true, filtered_preds, labels=labels, zero_division=0, target_names=labels)
print(f"Accuracy: {accuracy:.4f}")
print("\nClassification Report:")
print(report)
# (Optional: show sample predictions)
# Out:
# Running Zero-Shot Classification on Test Set (485 examples) using google/gemma-3-1b-it...
#   0%|          | 0/485 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:636: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:653: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `64` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`.
#   warnings.warn(
# Generated Text (Gemma): Positive
# Generated Text (Gemma): Negative
# Generated Text (Gemma): Negative
# Generated Text (Gemma): Positive
# Generated Text (Gemma): Positive
# Generated Text (Gemma): Positive
# Generated Text (Gemma): Positive
# ...

# %%
print("\n--- Base Open Source Model: Zero-Shot Evaluation Results ---")
# Filter out potential errors before calculating metrics
valid_indices = [i for i, p in enumerate(base_os_predictions) if p not in ["Error", "Unknown"]]
filtered_preds = [base_os_predictions[i] for i in valid_indices]
filtered_true = [true_labels[i] for i in valid_indices]

accuracy = accuracy_score(filtered_true, filtered_preds)
report = classification_report(filtered_true, filtered_preds, labels=labels, zero_division=0)

print(f"Accuracy: {accuracy:.4f}")
print("\nClassification Report:")
print(report)

# Show some example predictions
print("\nSample Predictions (Prediction | True Label):")
for i in range(min(10, len(test_dataset))):  # Show first 10
    print(f"- {base_os_predictions[i]} | {true_labels[i]}")
# Out:
# --- Base Open Source Model: Zero-Shot Evaluation Results ---
# Accuracy: 0.4598
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      neutral       0.90      0.16      0.27       290
#     negative       0.56      0.84      0.67        56
#     positive       0.37      0.94      0.53       139
#
#     accuracy                           0.46       485
#    macro avg       0.61      0.64      0.49       485
# weighted avg       0.71      0.46      0.39       485
#
#
# Sample Predictions (Prediction | True Label):
# - positive | neutral
# - negative | negative
# - negative | neutral
# - positive | positive
# - positive | neutral
# - positive | neutral
# - positive | neutral
# - positive | positive
# - positive | neutral
# - neutral | neutral

# %% [markdown]
# ### Practice Opportunity 3: Baseline Analysis
#
# 1.  **Interpret Results:** Look at the Accuracy and Classification Report for the base open-source model. How well does it perform "out of the box"? Are Precision/Recall/F1-scores high or low? Is performance similar across all classes (hawkish, dovish, neutral), or does it struggle with specific ones?
# 2.  **Prompt Sensitivity:** Modify the `system_prompt` inside `create_zeroshot_prompt`. Try making it simpler or more complex. For example, remove the list of labels and just say "Classify the sentiment". Re-run the evaluation. Does the performance change significantly? Why might small models be sensitive to prompt wording for zero-shot classification?

# %% [markdown]
# ## **Section 4: Fine-tuning the Open Source Model (PEFT/LoRA & SFTTrainer)** ✨⚙️
#
# Now for the exciting part! We'll fine-tune our base open-source model using the training data we prepared. We'll use **PEFT (LoRA)** to do this efficiently without needing massive amounts of VRAM. `SFTTrainer` from the `trl` library simplifies the training loop.
#
# **Key Concepts:**
# *   **PEFT (Parameter-Efficient Fine-Tuning):** Instead of updating all the billions of parameters in the LLM, PEFT methods like LoRA add small, trainable "adapter" layers. We only train these adapters, which is much faster and uses far less memory.
# *   **LoRA (Low-Rank Adaptation):** A popular PEFT technique that injects trainable low-rank matrices into the model's layers.
# *   **`SFTTrainer`:** A convenient Hugging Face trainer class designed for Supervised Fine-tuning tasks where the input is formatted text (like our prompts) and the model learns to generate the desired output (the label).
#
# **Steps:**
# 1.  **Load Base Model (again, if needed):** Ensure the base model and tokenizer are loaded, this time prepared for training (using `prepare_model_for_kbit_training`).
# 2.  **Configure LoRA:** Define `LoraConfig` specifying which parts of the model to adapt and the LoRA parameters (like rank `r`, `alpha`).
# 3.  **Configure Training Arguments:** Set hyperparameters like learning rate, batch size, number of epochs, output directory using `TrainingArguments`.
# 4.  **Initialize `SFTTrainer`:** Pass the model, tokenizer, datasets, LoRA config, and training arguments.
# 5.  **Start Training:** Call `trainer.train()`.
# 6.  **Save Adapter:** Save the trained LoRA adapter weights using `trainer.save_model()`.
# 7.  **Load Fine-tuned Model:** Load the base model *plus* the trained LoRA adapter weights for evaluation.

# %%
# Only proceed if model and data are ready

print("\n--- Preparing Model and Config for PEFT/LoRA Fine-tuning ---")

# --- Prepare model for k-bit training (important for quantized models) ---
base_os_model.gradient_checkpointing_enable()  # Saves memory during training
prepared_model = prepare_model_for_kbit_training(base_os_model)
print("Model prepared for k-bit training.")

# --- LoRA Configuration ---
# Target modules often include query/key/value layers in attention blocks
# This depends on the model architecture (use print(prepared_model) to inspect layers)
# For Qwen-based models, common targets might be 'q_proj', 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj'
# Let's start with a reasonable default set
lora_config = LoraConfig(
    r=16,  # LoRA rank (dimension of adapter matrices). Higher rank = more parameters, potentially better fit but slower. 8, 16, 32 are common.
    lora_alpha=32,  # Scaling factor for LoRA weights (often 2*r).
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj"],  # Modules to apply LoRA to. ADJUST BASED ON MODEL!
    lora_dropout=0.05,  # Dropout probability for LoRA layers.
    bias="none",  # Usually set to 'none'.
    task_type="CAUSAL_LM",  # Task type for sequence generation.
)
print("LoRA Config created.")

# --- Apply PEFT to the model ---
# This replaces the target modules with LoRA layers
peft_model = get_peft_model(prepared_model, lora_config)
print("PEFT model created.")
peft_model.print_trainable_parameters()  # See how few parameters we're actually training!
# Out:
# --- Preparing Model and Config for PEFT/LoRA Fine-tuning ---
# Model prepared for k-bit training.
# LoRA Config created.
# PEFT model created.
# trainable params: 2,981,888 || all params: 1,002,867,840 || trainable%: 0.2973
# /usr/local/lib/python3.11/dist-packages/peft/mapping_func.py:73: UserWarning: You are trying to modify a model with PEFT for a second time. If you want to reload the model with a different config, make sure to call `.unload()` before.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/tuners/tuners_utils.py:167: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(

# %%
# prompt: code to zip and download the weights. /content/sentiment_finetuned_adapter

import shutil
import os

# Define the directory to zip
dir_to_zip = "/content/sentiment_finetuned_adapter"

# Create a zip archive of the directory
shutil.make_archive("sentiment_finetuned_adapter", 'zip', dir_to_zip)

# Download the zip file
from google.colab import files
files.download("sentiment_finetuned_adapter.zip")

# %%
# --- Training Arguments ---
# These hyperparameters control the training process. Adjust based on performance and time constraints.
output_dir = "./sentiment_finetuned_adapter"  # Directory to save adapter weights
training_args = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=4,  # Adjust based on GPU memory (2, 4, 8 typical for Colab)
    gradient_accumulation_steps=2,  # Effective batch size = batch_size * grad_accum_steps
    learning_rate=2e-4,  # Common starting point for LoRA
    num_train_epochs=4,  # Start with 1 epoch for faster iteration/testing. Increase to 2-3 if needed.
    logging_steps=25,  # Log training loss every N steps
    save_strategy="epoch",  # Save adapter checkpoint at the end of each epoch
    # optim="paged_adamw_8bit", # Use paged optimizer for memory efficiency (requires bitsandbytes >= 0.41.0) - try if memory issues occur
    fp16=not torch.cuda.is_bf16_supported(),  # Use fp16 if bf16 not supported
    bf16=torch.cuda.is_bf16_supported(),  # Use bf16 if supported (preferred)
    max_grad_norm=0.3,  # Gradient clipping
    warmup_ratio=0.03,  # Learning rate warmup
    lr_scheduler_type="constant",  # Or "linear", "cosine"
    report_to="none",  # Disable wandb/tensorboard reporting for simplicity
)
print("Training Arguments set.")

# --- Initialize SFTTrainer ---
trainer = SFTTrainer(
    model=peft_model,  # The PEFT model
    args=training_args,  # Training arguments
    train_dataset=sft_train_dataset,  # Formatted training data
    peft_config=lora_config,  # Pass the LoRA config again
)
print("SFTTrainer initialized.")

# --- Start Fine-tuning ---
print("\n--- Starting Fine-tuning... ---")
try:
    training_results = trainer.train()
    # training_results = trainer.train(resume_from_checkpoint=True) #Uncomment to run from check point
    print("--- Fine-tuning Complete! ---")
    print(training_results)

    # --- Save the LoRA Adapter ---
    print(f"Saving LoRA adapter model to {output_dir}...")
    trainer.save_model(output_dir)  # Saves only the adapter weights
    # Also save the tokenizer for consistency
    base_os_tokenizer.save_pretrained(output_dir)
    print("Adapter and tokenizer saved.")

    # --- Clean up memory (important before loading for evaluation) ---
    del trainer
    del peft_model  # Delete the model used for training
    # del prepared_model # Optional
    # del base_os_model # Keep the original base model if needed later, or delete
    torch.cuda.empty_cache()
    import gc

    gc.collect()
    print("Cleaned up training objects from memory.")

    fine_tuning_successful = True

except Exception as e:
    print(f"Error during fine-tuning: {e}")
    fine_tuning_successful = False
# Out:
# Training Arguments set.
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# SFTTrainer initialized.
#
# --- Starting Fine-tuning... ---
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='2180' max='2180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2180/2180 19:42, Epoch 3/4]
# ...

# %% [markdown]
# ### Practice Opportunity 4: Fine-tuning Configuration
#
# 1.  **Trainable Parameters:** Look at the output of `peft_model.print_trainable_parameters()`. What percentage of the total parameters are actually being trained? Why is this number so small, and why is that beneficial in Colab?
# 2.  **Training Arguments:** Identify two key `TrainingArguments` and explain their purpose. For example:
#     *   `per_device_train_batch_size`: What does it control? What happens if you set it too high in Colab?
#     *   `num_train_epochs`: What does this determine? What's the trade-off between training for more or fewer epochs?

# %% [markdown]
# ## **Section 5: Evaluation - Fine-tuned Open Source Model** ✅📊
#
# Now, let's evaluate the model we just fine-tuned! We need to load the base model again but *merge* it with the trained LoRA adapter weights. Then, we run the same zero-shot classification evaluation process as in Section 3 on the test set.
#
# **Steps:**
# 1.  **Load the Fine-tuned Model:**
#     *   Load the base model configuration (quantized).
#     *   Load the base model weights.
#     *   Load the PEFT adapter weights from the directory where we saved them (`output_dir`).
#     *   Combine the base model and the adapter.
# 2.  **Run Inference:** Use the *same* zero-shot classification function (`classify_zero_shot_os`) and prompt template on the test set, but pass the *fine-tuned PEFT model*.
# 3.  **Calculate Metrics:** Compute accuracy and the classification report.
# 4.  **Compare:** Compare these results directly with the baseline zero-shot results from Section 3.

# %%
tuned_os_predictions = []

# Only proceed if fine-tuning seemed successful and saved adapter exists
adapter_path = "./sentiment_finetuned_adapter"

print(f"\n--- Loading Fine-tuned Open Source Model from {adapter_path} ---")

# --- Load Tokenizer (from saved adapter dir) ---
tuned_os_tokenizer = AutoTokenizer.from_pretrained(adapter_path, trust_remote_code=True)

# --- Load Base Model (Quantized) ---
# It's often cleaner to reload the base model before applying the adapter
quantization_config = BitsAndBytesConfig(load_in_4bit=True)
base_model_reload = AutoModelForCausalLM.from_pretrained(
    os_model_id,  # The original base model ID
    quantization_config=quantization_config,
    device_map="auto",
    trust_remote_code=True,
)
# Set pad token ID on the reloaded model config if needed
if tuned_os_tokenizer.pad_token_id is not None:
    base_model_reload.config.pad_token_id = tuned_os_tokenizer.pad_token_id

# --- Load PEFT Adapter and Merge (or use directly) ---
# Option A: Load PeftModel directly (uses base + adapter without merging) - Often preferred for memory
from peft import PeftModel

tuned_os_model = PeftModel.from_pretrained(base_model_reload, adapter_path)
print("Loaded PEFT model (base + adapter).")

# Option B: Merge weights (creates a new model, uses more memory/disk but might be faster for inference?)
# merged_model = peft_model.merge_and_unload()
# tuned_os_model = merged_model # Use the merged model
# print("Merged PEFT adapter into base model.")

# Ensure model is in evaluation mode
tuned_os_model.eval()
print("Fine-tuned OS model loaded successfully.")


# --- Evaluate on Test Set ---

# Assuming true_labels list was populated in Section 3
if "true_labels" not in locals() or not true_labels:
    print("Warning: true_labels not found from Section 3. Re-extracting.")
    true_labels = [ex["sentiment"] for ex in test_dataset]

for example in tqdm(test_dataset):  # Use tqdm for progress bar
    sentence = example["text"]
    # Use the SAME zero-shot function, but pass the TUNED model
    predicted_label = classify_zero_shot_os_gemma(sentence, tuned_os_model, tuned_os_tokenizer)
    tuned_os_predictions.append(predicted_label)

print("\n--- Fine-Tuned Open Source Model: Evaluation Results ---")
valid_indices_tuned = [i for i, p in enumerate(tuned_os_predictions) if p not in ["Error", "Unknown"]]
filtered_preds_tuned = [tuned_os_predictions[i] for i in valid_indices_tuned]
# Ensure we use the same true labels corresponding to the test set order
filtered_true_tuned = [
    true_labels[i] for i in valid_indices_tuned
]  # Use true_labels from Section 3 evaluation run


accuracy_tuned = accuracy_score(filtered_true_tuned, filtered_preds_tuned)
report_tuned = classification_report(
    filtered_true_tuned, filtered_preds_tuned, labels=labels, zero_division=0
)

print(f"Accuracy: {accuracy_tuned:.4f}")
print("\nClassification Report:")
print(report_tuned)

# --- Compare with Base OS Model ---
print("\n--- Comparison with Base OS Model ---")

print(f"Base OS Accuracy:      {accuracy:.4f}")
print(f"Fine-Tuned OS Accuracy: {accuracy_tuned:.4f}")
improvement = accuracy_tuned - accuracy
print(f"Improvement:           {improvement:+.4f}")
# Out:
# --- Loading Fine-tuned Open Source Model from ./sentiment_finetuned_adapter ---
# Loaded PEFT model (base + adapter).
# Fine-tuned OS model loaded successfully.
#   0%|          | 0/485 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:636: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:653: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `64` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`.
#   warnings.warn(
# Generated Text (Gemma): positive
# ...

# %% [markdown]
# ### Practice Opportunity 5: Fine-tuning Impact
#
# 1.  **Performance Gain:** Compare the Accuracy and the F1-scores (especially the macro/weighted average) from the Classification Reports in Section 3 (Base OS) and Section 5 (Tuned OS). How much did fine-tuning improve performance on this specific task?
# 2.  **Class-Specific Improvement:** Did fine-tuning improve performance significantly for classes the base model struggled with? (Look at the per-class F1-scores).
# 3.  **Why the Improvement?** Based on what fine-tuning does, explain *why* the performance likely improved. What did the model learn during the fine-tuning process?

# %% [markdown]
# # Practice Opportunity Solutions

# %% [markdown]
# ### Practice Opportunity Solution 1: Setup & GPU Check
#
# 1.  **GPU Capability:**
#     *   **Verification:** The output should show `GPU detected: [GPU Name]` (e.g., Tesla T4, A100). It will also specify if `bfloat16` is supported or if it's using `float16`. Seeing `❌ FATAL: No GPU detected.` means you *must* enable a GPU runtime (Runtime -> Change runtime type -> Select GPU).
#     *   **Why GPU is Critical:** Fine-tuning, even with PEFT/LoRA, involves backpropagation and gradient updates across potentially millions (for LoRA) or billions (full tuning) of parameters. These operations are matrix-multiplication heavy and computationally intensive. A CPU would take an extremely long time (days or weeks) to complete the training required in this project, whereas a GPU can do it in minutes or hours. Zero-shot inference (like in previous projects) is less demanding, but training requires significantly more computational power provided efficiently by GPUs.

# %% [markdown]
# --------------------------

# %% [markdown]
# ### Practice Opportunity Solution 2: Data Inspection
#
# 1.  **Label Balance:**
#     *   **Verification:** Examine the table printed under "Label Distribution". It will show the counts for 'hawkish', 'dovish', and 'neutral'. Observe if the numbers are similar (balanced) or if one class dominates (imbalanced). For `FinanceMTEB/FOMC`, it's relatively balanced but might have variations.
#     *   **Impact of Imbalance:** If a dataset is highly imbalanced, a model might become biased towards predicting the majority class, achieving high accuracy simply by ignoring the minority classes. Metrics like F1-score (especially weighted or macro averages) become more important than accuracy in such cases, as they account for precision and recall across all classes. Techniques like over/under-sampling or using class weights during training might be needed for severely imbalanced datasets.
#
# 2.  **SFT Format:**
#     *   **Verification:** The sample output shows a structure like:
#         ```
#         <|im_start|>system
#         Classify the sentiment... postive,neutral or negative.<|im_end|>
#         <|im_start|>user
#         Sentence: [Actual sentence text]<|im_end|>
#         <|im_start|>assistant
#         negative<|im_end|>
#         ```
#     *   **Why Include Label:** `SFTTrainer` works by training the model on a **Causal Language Modeling** objective. This means the model learns to predict the *next token* in a sequence. By providing the entire formatted text (including the `assistant`'s response, i.e., the correct label), the model learns that after seeing the system prompt and the user sentence, the most likely next token sequence is the correct label (e.g., "negative" followed by `<|im_end|>`). It learns the mapping from input (prompt + sentence) to output (label) implicitly through next-token prediction on this structured text.

# %% [markdown]
# ---------------------------

# %% [markdown]
# ### Practice Opportunity Solution 3: Baseline Analysis
#
# 1.  **Interpret Results:**
#     *   **Guidance:** Look at the `Accuracy:` value printed. A value close to 1.0 is perfect, 0.5 is okay for two classes, and around 0.33 might be near random chance for three balanced classes. Then examine the `Classification Report`. Look at the `weighted avg` or `macro avg` for `f1-score`. An F1 score above 0.7-0.8 might be considered decent, while scores below 0.5-0.6 suggest poor performance. Check the individual rows for 'hawkish', 'dovish', 'neutral'. If the F1-score for one class is much lower than others, the model struggles specifically with that category. For a 1.5B model zero-shot on this task, expect mediocre results (e.g., accuracy perhaps between 0.4 and 0.6, low F1 scores).
#
# 2.  **Prompt Sensitivity:**
#     *   **Code:** Modify the `system_prompt` within `create_zeroshot_prompt`:
#         ```python
#         # Try simplifying:
#         system_prompt = f"What is the sentiment of the following FOMC sentence? Choose one: {', '.join(labels)}."
#         # Or try being more direct without listing labels (might confuse the model):
#         # system_prompt = "Classify the FOMC sentence sentiment as hawkish, dovish, or neutral. Output only the label."
#         ```
#     *   **Observation:** Re-running the evaluation after changing the prompt might change the accuracy and classification report. The performance could improve slightly if the new prompt is clearer *to this specific model*, or degrade if it's more ambiguous or doesn't explicitly constrain the output format well enough.
#     *   **Why Sensitivity:** Smaller models have less capacity for generalization and understanding nuanced instructions compared to larger ones. They rely more heavily on the exact phrasing and structure of the prompt. A poorly worded prompt might not effectively trigger the desired classification behavior, leading the model to generate conversational text, refuse to answer, or pick a label almost randomly. Explicitly listing the allowed labels and demanding ONLY one label in the output is crucial.

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ### Practice Opportunity Solution 4: Fine-tuning Configuration
#
# 1.  **Trainable Parameters:**
#     *   **Verification:** The line `peft_model.print_trainable_parameters()` will output something like: `trainable params: 4,718,592 || all params: 1,321,330,752 || trainable%: 0.3571`.
#     *   **Why Small %:** This percentage (often < 1%) is small because LoRA only introduces and trains the parameters within the small adapter layers (`q_proj`, `k_proj`, etc. in our config), *not* the original billions of parameters in the base model (which remain frozen).
#     *   **Benefits:** Training far fewer parameters requires significantly less GPU memory (VRAM), making it feasible to fine-tune large models on hardware like Colab's T4 GPU. It's also much faster than full fine-tuning.
#
# 2.  **Training Arguments:**
#     *   **`per_device_train_batch_size`:** This controls how many training examples (formatted prompts) are processed simultaneously on the GPU in one forward/backward pass. If set too high, it will exceed the GPU's memory, causing an Out-Of-Memory (OOM) error and crashing the training. If set too low (e.g., 1), training might be slow, and gradient updates might be noisy. It needs to be balanced with `gradient_accumulation_steps`.
#     *   **`num_train_epochs`:** This determines how many times the entire training dataset is passed through the model for training. One epoch means seeing every training example once. More epochs allow the model more chances to learn from the data but increase training time and risk **overfitting** (where the model memorizes the training data too well and performs poorly on unseen data). Starting with 1-3 epochs is common for fine-tuning.

# %% [markdown]
# --------------------------------------

# %% [markdown]
# ### Practice Opportunity Solution 5: Fine-tuning Impact
#
# 1.  **Performance Gain:**
#     *   **Action:** Compare the `Accuracy:` value and the `weighted avg` `f1-score` from the report printed at the end of Section 5 (Tuned OS) with the corresponding values from the report printed at the end of Section 3 (Base OS).
#     *   **Expected Observation:** You should generally see a noticeable **increase** in both accuracy and F1-score after fine-tuning. The magnitude of the improvement depends on the base model, the dataset size/quality, and the tuning hyperparameters, but gains from (e.g.) 0.5 accuracy to 0.7-0.9 accuracy are common for classification tasks like this.
#
# 2.  **Class-Specific Improvement:**
#     *   **Action:** Look at the rows for 'positive', 'negative', and 'neutral' in both the Section 3 and Section 5 classification reports. Compare the `f1-score` for each class individually.
#     *   **Expected Observation:** Fine-tuning often helps most with classes the base model performed poorly on. If the base model had a very low F1-score for 'negative', for instance, you'd expect the fine-tuned model's F1-score for 'negative' to be significantly higher. The goal is more balanced performance across all classes.
#
# 3.  **Why the Improvement?:**
#     *   **Explanation:** Pre-trained LLMs have general language understanding but lack specific knowledge about the nuances and vocabulary of a specialized domain like Financial News. Fine-tuning **adapts** the model to this specific task and data distribution. During fine-tuning with SFTTrainer (using the causal LM objective on formatted text), the model learns:
#         *   The specific vocabulary and phrasing used in Financial News.
#     Essentially, it specializes its knowledge for *this particular classification task*, moving beyond general understanding to task-specific expertise.

# %% [markdown]
# ----------------------------
